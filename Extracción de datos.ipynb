# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import io

# %%
df=pd.read_csv('Ventas_totales_supermercados.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   indice_tiempo                        65 non-null     object
#  1   ventas_precios_corrientes            65 non-null     float64
#  2   ventas_precios_constantes            65 non-null     float64
#  3   ventas_totales_canal_venta           65 non-null     float64
#  4   salon_ventas                         65 non-null     float64
#  5   canales_on_line                      65 non-null     float64
#  6   ventas_totales_medio_pago            65 non-null     float64
#  7   efectivo                             65 non-null     float64
#  8   tarjetas_debito                      65 non-null     float64
#  9   tarjetas_credito                     65 non-null     float64
#  10  otros_medios                         65 non-null     float64
# ...

# %%
#Con este filtro podemos ver datos específicos dentro de nuestra base de datos
#en este caso se muestra los datos de ventas del 01-02-2017 en específico
#NOTA:Este filtro de aplico en la variable cualitativa de "Indice de Tiempo"
f1=df[df["indice_tiempo"]=="2017-02-01"]
f1
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 1    2017-02-01                    25994.2                    25223.4
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 1                2.599420e+07  2.574918e+07       245020.769
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 1               2.599420e+07  9.719067e+06     6.438494e+06      8.309150e+06
#
#    ...       almacen     panaderia       lacteos        carnes  \
# 1  ...  6.576625e+06  925618.61472  2.855640e+06  2.600084e+06
#
#    verduleria_fruteria  alimentos_preparados_rotiseria  \
# 1         1.026167e+06                    328288.69508
#
#    articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 1                   4.053284e+06                         672290.51653
#
#    electronicos_articulos_hogar         otros
# 1                  1.257662e+06  2.354085e+06
#
# [1 rows x 24 columns]

# %%
#Este segundo filtro nos muestra los datos
#del tercer mes de cada año dentro de la base datos
#Estos datos se encuentran ubicados en filas no consecutivas
f2=df.iloc[[2,14,26,38,50,62],:]
f2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 2     2017-03-01                    27780.0                    26334.3
# 14    2018-03-01                    36531.3                    28846.7
# 26    2019-03-01                    51065.7                    24647.7
# 38    2020-03-01                    85778.0                    26996.7
# 50    2021-03-01                   107225.9                    24627.6
# 62    2022-03-01                   168982.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# 14                3.653129e+07  3.605541e+07     4.758783e+05
# 26                5.106569e+07  5.034778e+07     7.179116e+05
# 38                8.577803e+07  8.417488e+07     1.603156e+06
# 50                1.072259e+08  1.032432e+08     3.982669e+06
# 62                1.689825e+08  1.643211e+08     4.661395e+06
#
# ...

# %%
#El tercer filtro muestra solo ciertas columnas que hemos elegido
#de la base datos (indice_tiempo,ventas_precios_corrientes,salon_ventas,
#ventas_totales_medio)
f3=df.iloc[:,[0,1,4,6]]
f3
# Out:
#    indice_tiempo  ventas_precios_corrientes  salon_ventas  \
# 0     2017-01-01                    27858.9  2.759173e+07
# 1     2017-02-01                    25994.2  2.574918e+07
# 2     2017-03-01                    27780.0  2.747223e+07
# 3     2017-04-01                    29134.3  2.882748e+07
# 4     2017-05-01                    27969.0  2.756931e+07
# ..           ...                        ...           ...
# 60    2022-01-01                   154517.1  1.496976e+08
# 61    2022-02-01                   152202.6  1.484065e+08
# 62    2022-03-01                   168982.5  1.643211e+08
# 63    2022-04-01                   177148.1  1.730038e+08
# 64    2022-05-01                   179639.2  1.753585e+08
#
#     ventas_totales_medio_pago
# 0                2.785887e+07
# 1                2.599420e+07
# 2                2.778001e+07
# 3                2.913427e+07
# 4                2.796900e+07
# ..                        ...
# 60               1.545171e+08
# ...

# %%
#Filtro de filas vs columnas 
#En este filtro surgió el error "None of [Index(['2017-01-01'], dtype='object')] are in the [index]"
f4=df.loc[["2017-01-01"], ["ventas_totales_canal_venta"]]
f4

# %%
#comparación
f5=df.head()
f5
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0    2017-01-01                    27858.9                    27477.3
# 1    2017-02-01                    25994.2                    25223.4
# 2    2017-03-01                    27780.0                    26334.3
# 3    2017-04-01                    29134.3                    27045.9
# 4    2017-05-01                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                2.785887e+07  2.759173e+07       267141.956
# 1                2.599420e+07  2.574918e+07       245020.769
# 2                2.778001e+07  2.747223e+07       307777.804
# 3                2.913427e+07  2.882748e+07       306792.733
# 4                2.796900e+07  2.756931e+07       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0               2.785887e+07  1.023010e+07     6.864575e+06      9.047205e+06
# ...
