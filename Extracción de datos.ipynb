# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import io

# %%
df=pd.read_csv('Ventas_totales_supermercados.csv',index_col=0)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65 entries, 2017-01-01 to 2022-05-01
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ventas_precios_corrientes            65 non-null     float64
#  1   ventas_precios_constantes            65 non-null     float64
#  2   ventas_totales_canal_venta           65 non-null     float64
#  3   salon_ventas                         65 non-null     float64
#  4   canales_on_line                      65 non-null     float64
#  5   ventas_totales_medio_pago            65 non-null     float64
#  6   efectivo                             65 non-null     float64
#  7   tarjetas_debito                      65 non-null     float64
#  8   tarjetas_credito                     65 non-null     float64
#  9   otros_medios                         65 non-null     float64
# ...

# %%
#Con este filtro podemos ver datos específicos dentro de nuestra base de datos
#en este caso se muestra los datos de ventas del 01-02-2017 en específico
#NOTA:Este filtro de aplico en la variable cualitativa de "Indice de Tiempo"
f1=df[df["indice_tiempo"]=="2017-02-01"]
f1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'indice_tiempo'
# ...

# %%
#Este segundo filtro nos muestra los datos
#del tercer mes de cada año dentro de la base datos
#Estos datos se encuentran ubicados en filas no consecutivas
f2=df.iloc[[2,14,26,38,50,62],:]
f2
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-03-01                       27780.0                    26334.3
# 2018-03-01                       36531.3                    28846.7
# 2019-03-01                       51065.7                    24647.7
# 2020-03-01                       85778.0                    26996.7
# 2021-03-01                      107225.9                    24627.6
# 2022-03-01                      168982.5                    24612.4
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# 2017-03-01                   2.778001e+07  2.747223e+07     3.077778e+05
# 2018-03-01                   3.653129e+07  3.605541e+07     4.758783e+05
# 2019-03-01                   5.106569e+07  5.034778e+07     7.179116e+05
# 2020-03-01                   8.577803e+07  8.417488e+07     1.603156e+06
# 2021-03-01                   1.072259e+08  1.032432e+08     3.982669e+06
# ...

# %%
#El tercer filtro muestra solo ciertas columnas que hemos elegido
#de la base datos (indice_tiempo,ventas_precios_corrientes,salon_ventas,
#ventas_totales_medio)
f3=df.iloc[:,[0,1,4,6]]
f3
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
# ...                                  ...                        ...
# 2022-01-01                      154517.1                    25463.4
# 2022-02-01                      152202.6                    23802.1
# 2022-03-01                      168982.5                    24612.4
# 2022-04-01                      177148.1                    24140.5
# 2022-05-01                      179639.2                    23234.2
#
#                canales_on_line      efectivo
# indice_tiempo
# 2017-01-01        2.671420e+05  1.023010e+07
# ...

# %%
#Filtro de filas vs columnas 
f4=df.loc[["2017-01-01","2022-01-01"],["ventas_precios_constantes"]]
f4
# Out:
#                ventas_precios_constantes
# indice_tiempo
# 2017-01-01                       27477.3
# 2022-01-01                       25463.4

# %%
#comparación
f5=df.head()
f5
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# 2017-01-01                   2.785887e+07  2.759173e+07       267141.956
# 2017-02-01                   2.599420e+07  2.574918e+07       245020.769
# 2017-03-01                   2.778001e+07  2.747223e+07       307777.804
# 2017-04-01                   2.913427e+07  2.882748e+07       306792.733
# 2017-05-01                   2.796900e+07  2.756931e+07       399693.262
#
#                ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# ...

# %%
#Filtro de variables cuantitativas
#Filtro por condición de mostrar los valores de ventas totales medio de pago mayores o iguales a 30,000
f6=df[df["ventas_totales_medio_pago"]>=30000]
f6
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
# ...                                  ...                        ...
# 2022-01-01                      154517.1                    25463.4
# 2022-02-01                      152202.6                    23802.1
# 2022-03-01                      168982.5                    24612.4
# 2022-04-01                      177148.1                    24140.5
# 2022-05-01                      179639.2                    23234.2
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# ...

# %%
#Conectores logicos
#Se mostraran solo los valores donde "ventas_precios_corrientes" sea mayor a 20000 y donde "ventas_precios_constantes"
#sea mayor a 30000
f7=df[(df["ventas_precios_corrientes"]>20000)&(df["ventas_precios_constantes"]>30000)]
f7
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-12-01                       40766.3                    34084.5
# 2018-12-01                       57204.0                    31136.1
# 2021-12-01                      183983.2                    31595.7
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# 2017-12-01                   4.076632e+07  4.032029e+07     4.460368e+05
# 2018-12-01                   5.720396e+07  5.645236e+07     7.515994e+05
# 2021-12-01                   1.839832e+08  1.788667e+08     5.116431e+06
#
#                ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# indice_tiempo
# 2017-12-01                  4.076632e+07  1.371031e+07     1.107010e+07
# 2018-12-01                  5.720396e+07  1.937298e+07     1.625221e+07
# 2021-12-01                  1.839832e+08  5.664003e+07     5.543219e+07
#
# ...

# %%
#filtro o
#Se mostraran valores donde "tarjetas_debito" sea mayor a 5,000,000 o donde la variable "tarjetas_credito"
#sea mayor a 500,000,000
f8=df[(df["tarjetas_debito"]>5000000)|(df["tarjetas_credito"]>500000000)]
f8
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
# ...                                  ...                        ...
# 2022-01-01                      154517.1                    25463.4
# 2022-02-01                      152202.6                    23802.1
# 2022-03-01                      168982.5                    24612.4
# 2022-04-01                      177148.1                    24140.5
# 2022-05-01                      179639.2                    23234.2
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# ...

# %%
#filtro not negación
#Se muestran todos los valores que no sean mayores o iguales a 40,000,000 en la variable
# "ventas_totales_grupo_articulos"
f9=df[~(df["ventas_totales_grupo_articulos"]>=40000000)]
f9
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
# 2017-06-01                       29132.7                    26365.4
# 2017-07-01                       31182.3                    27819.4
# 2017-08-01                       31154.9                    27394.1
# 2017-09-01                       30521.5                    26404.3
# 2017-10-01                       32446.0                    27766.7
# 2017-11-01                       33629.0                    28425.3
# 2018-01-01                       32479.2                    26736.7
# 2018-02-01                       31736.8                    25650.7
# ...

# %%
#Convertir archivo filtrado a CSV
f1.to_csv("Filtro1.csv")
f2.to_csv("Filtro2.csv")
f3.to_csv("Filtro3.csv")
f4.to_csv("Filtro4.csv")
f5.to_csv("Filtro5.csv")
f6.to_csv("Filtro6.csv")
f7.to_csv("Filtro7.csv")
f8.to_csv("Filtro8.csv")
f9.to_csv("Filtro9.csv")

# %%
pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
